# %%
import matplotlib.pyplot as plt
import numpy as np

#sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
#mtnc_time_sc1_run_1 = tuple(sc_1_mtnc_1_run_1)

#print(mtnc_time_sc1_run_1)

sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
if  'failure' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'failure']


keys_list = list(sc_1_mtnc_1_run_1.keys())
values_list = list(sc_1_mtnc_1_run_1.values())

print("Keys:", keys_list)
print("Values:", values_list)

fig, ax = plt.subplots(figsize=(15, 20)) 

ax.barh(keys_list, values_list)


ax.xaxis.tick_top()
ax.yaxis.tick_left()

ax.set_xlabel('Maintenance1 Run1 Time for Scale1', position=(0.5, 1.02))
ax.set_ylabel('Python File', position=(0, 1.02))
ax.set_title('Execution Time(Seconds)', position=(0.5, 1.05))


plt.tight_layout()  
plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py', 'test_linhan.py']
# Values: [0.0844879150390625, 0.013923883438110352, 0.9074771404266357, 0.27125000953674316, 0.04225301742553711, 0.042488813400268555, 0.1302320957183838, 0.016154766082763672, 0.034861087799072266, 0.01619100570678711, 0.03455495834350586, 0.02875494956970215]

# %%
import matplotlib.pyplot as plt
import numpy as np

#sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
#mtnc_time_sc1_run_1 = tuple(sc_1_mtnc_1_run_1)

#print(mtnc_time_sc1_run_1)

sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
if  'failure' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'failure']

keys_list = list(sc_1_mtnc_1_run_1.keys())
values_list = list(sc_1_mtnc_1_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run1 Time for Scale1')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
#mtnc_time_sc1_run_1 = tuple(sc_1_mtnc_1_run_1)

#print(mtnc_time_sc1_run_1)

sc_1_mtnc_1_run_2 = {'DF_CS_delete.py': 0.031365156173706055, 'DF_I_delete.py': 0.011495828628540039, 'DF_SS_delete.py': 0.607820987701416, 'DF_WS_delete.py': 0.19784069061279297, 'failure': 20.003587245941162, 'LF_CR_insert.py': 0.03851795196533203, 'LF_CS_insert.py': 0.033492088317871094, 'LF_I_insert.py': 0.14211392402648926, 'LF_SR_insert.py': 0.015489816665649414, 'LF_SS_insert.py': 0.021422863006591797, 'LF_WR_insert.py': 0.014980077743530273, 'LF_WS_insert.py': 0.02646017074584961, 'test_linhan.py': 0.03458380699157715}
if  'failure' in sc_1_mtnc_1_run_2:
    del sc_1_mtnc_1_run_2[ 'failure']

keys_list = list(sc_1_mtnc_1_run_2.keys())
values_list = list(sc_1_mtnc_1_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run2 Time for Scale1')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
#mtnc_time_sc1_run_1 = tuple(sc_1_mtnc_1_run_1)

#print(mtnc_time_sc1_run_1)

sc_1_mtnc_2_run_1 = {'DF_CS_delete.py': 0.07776284217834473, 'DF_I_delete.py': 0.45646095275878906, 'DF_SS_delete.py': 0.7255277633666992, 'DF_WS_delete.py': 0.23304486274719238, 'failure': 20.00579810142517, 'LF_CR_insert.py': 0.0344851016998291, 'LF_CS_insert.py': 0.03538203239440918, 'LF_I_insert.py': 0.14161896705627441, 'LF_SR_insert.py': 0.01501011848449707, 'LF_SS_insert.py': 0.023398160934448242, 'LF_WR_insert.py': 0.015402078628540039, 'LF_WS_insert.py': 0.02540111541748047, 'test_linhan.py': 0.028169870376586914}
if  'failure' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'failure']

keys_list = list(sc_1_mtnc_2_run_1.keys())
values_list = list(sc_1_mtnc_2_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run1 Time for Scale1')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


sc_1_mtnc_2_run_2 = {'DF_CS_delete.py': 0.030813217163085938, 'DF_I_delete.py': 0.010808944702148438, 'DF_SS_delete.py': 0.6375858783721924, 'DF_WS_delete.py': 0.19521093368530273, 'failure': 20.00576901435852, 'LF_CR_insert.py': 0.03650808334350586, 'LF_CS_insert.py': 0.03334188461303711, 'LF_I_insert.py': 0.14561891555786133, 'LF_SR_insert.py': 0.01435708999633789, 'LF_SS_insert.py': 0.022155046463012695, 'LF_WR_insert.py': 0.014965057373046875, 'LF_WS_insert.py': 0.029603004455566406, 'test_linhan.py': 0.02772212028503418}
if  'failure' in sc_1_mtnc_2_run_2:
    del sc_1_mtnc_2_run_2[ 'failure']

keys_list = list(sc_1_mtnc_2_run_2.keys())
values_list = list(sc_1_mtnc_2_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run2 Time for Scale1')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


sc_3_mtnc_1_run_1 = {'DF_CS_delete.py': 0.11405229568481445, 'DF_I_delete.py': 0.02390289306640625, 'DF_SS_delete.py': 0.18929219245910645, 'DF_WS_delete.py': 0.09778285026550293, 'failure': 20.00570321083069, 'LF_CR_insert.py': 0.044631004333496094, 'LF_CS_insert.py': 0.04781532287597656, 'LF_I_insert.py': 0.14746904373168945, 'LF_SR_insert.py': 0.02198314666748047, 'LF_SS_insert.py': 0.04401206970214844, 'LF_WR_insert.py': 0.018975019454956055, 'LF_WS_insert.py': 0.036560773849487305, 'test_linhan.py': 0.02629709243774414}
if  'failure' in sc_3_mtnc_1_run_1:
    del sc_3_mtnc_1_run_1[ 'failure']

keys_list = list(sc_3_mtnc_1_run_1.keys())
values_list = list(sc_3_mtnc_1_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run1 Time for Scale3')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


sc_3_mtnc_1_run_2 = {'DF_CS_delete.py': 0.0364532470703125, 'DF_I_delete.py': 0.022266149520874023, 'DF_SS_delete.py': 0.028244972229003906, 'DF_WS_delete.py': 0.01862335205078125, 'failure': 20.005665063858032, 'LF_CR_insert.py': 0.04490399360656738, 'LF_CS_insert.py': 0.03934216499328613, 'LF_I_insert.py': 0.14059996604919434, 'LF_SR_insert.py': 0.018616199493408203, 'LF_SS_insert.py': 0.030556917190551758, 'LF_WR_insert.py': 0.017981767654418945, 'LF_WS_insert.py': 0.031950950622558594, 'test_linhan.py': 0.028422117233276367}
if  'failure' in sc_3_mtnc_1_run_2:
    del sc_3_mtnc_1_run_2[ 'failure']

keys_list = list(sc_3_mtnc_1_run_2.keys())
values_list = list(sc_3_mtnc_1_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run2 Time for Scale3')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_3_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04625272750854492, 'DF_I_delete.py': 0.02321791648864746, 'DF_SS_delete.py': 0.027719974517822266, 'DF_WS_delete.py': 0.018450260162353516, 'failure': 20.00582218170166, 'LF_CR_insert.py': 0.04858875274658203, 'LF_CS_insert.py': 0.05615115165710449, 'LF_I_insert.py': 0.14717602729797363, 'LF_SR_insert.py': 0.025307893753051758, 'LF_SS_insert.py': 0.05813288688659668, 'LF_WR_insert.py': 0.017707109451293945, 'LF_WS_insert.py': 0.046903133392333984, 'test_linhan.py': 0.028213977813720703}
if  'failure' in sc_3_mtnc_2_run_1:
    del sc_3_mtnc_2_run_1[ 'failure']

keys_list = list(sc_3_mtnc_2_run_1.keys())
values_list = list(sc_3_mtnc_2_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run1 Time for Scale3')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_3_mtnc_2_run_2 = {'DF_CS_delete.py': 0.01627492904663086, 'DF_I_delete.py': 0.022578001022338867, 'DF_SS_delete.py': 0.025724172592163086, 'DF_WS_delete.py': 0.016866683959960938, 'failure': 20.005707025527954, 'LF_CR_insert.py': 0.04039788246154785, 'LF_CS_insert.py': 0.03652620315551758, 'LF_I_insert.py': 0.15407395362854004, 'LF_SR_insert.py': 0.016583919525146484, 'LF_SS_insert.py': 0.0316929817199707, 'LF_WR_insert.py': 0.01673412322998047, 'LF_WS_insert.py': 0.032000064849853516, 'test_linhan.py': 0.02860283851623535}
if  'failure' in sc_3_mtnc_2_run_2:
    del sc_3_mtnc_2_run_2[ 'failure']

keys_list = list(sc_3_mtnc_2_run_2.keys())
values_list = list(sc_3_mtnc_2_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run2 Time for Scale3')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_5_mtnc_1_run_1 = {'DF_CS_delete.py': 0.10871601104736328, 'DF_I_delete.py': 0.03187394142150879, 'DF_SS_delete.py': 0.13074398040771484, 'DF_WS_delete.py': 0.09054207801818848, 'failure': 20.005099773406982, 'LF_CR_insert.py': 0.04679083824157715, 'LF_CS_insert.py': 0.0474088191986084, 'LF_I_insert.py': 0.16495203971862793, 'LF_SR_insert.py': 0.0230867862701416, 'LF_SS_insert.py': 0.048413991928100586, 'LF_WR_insert.py': 0.019726037979125977, 'LF_WS_insert.py': 0.03803396224975586, 'test_linhan.py': 0.026525020599365234}
if  'failure' in sc_5_mtnc_1_run_1:
    del sc_5_mtnc_1_run_1[ 'failure']

keys_list = list(sc_5_mtnc_1_run_1.keys())
values_list = list(sc_5_mtnc_1_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run1 Time for Scale5')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_5_mtnc_1_run_2 = {'DF_CS_delete.py': 0.04250502586364746, 'DF_I_delete.py': 0.024409770965576172, 'DF_SS_delete.py': 0.03317975997924805, 'DF_WS_delete.py': 0.022706985473632812, 'failure': 20.00553297996521, 'LF_CR_insert.py': 0.04375815391540527, 'LF_CS_insert.py': 0.03802180290222168, 'LF_I_insert.py': 0.1459507942199707, 'LF_SR_insert.py': 0.018959999084472656, 'LF_SS_insert.py': 0.03332209587097168, 'LF_WR_insert.py': 0.017785072326660156, 'LF_WS_insert.py': 0.03195786476135254, 'test_linhan.py': 0.027806997299194336}
if  'failure' in sc_5_mtnc_1_run_2:
    del sc_5_mtnc_1_run_2[ 'failure']

keys_list = list(sc_5_mtnc_1_run_2.keys())
values_list = list(sc_5_mtnc_1_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run2 Time for Scale5')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_5_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04702186584472656, 'DF_I_delete.py': 0.024369239807128906, 'DF_SS_delete.py': 0.02764582633972168, 'DF_WS_delete.py': 0.017188072204589844, 'failure': 20.005616903305054, 'LF_CR_insert.py': 0.049051761627197266, 'LF_CS_insert.py': 0.06269097328186035, 'LF_I_insert.py': 0.14451193809509277, 'LF_SR_insert.py': 0.0255429744720459, 'LF_SS_insert.py': 0.06828713417053223, 'LF_WR_insert.py': 0.0190432071685791, 'LF_WS_insert.py': 0.053540706634521484, 'test_linhan.py': 0.029045820236206055}
if  'failure' in sc_5_mtnc_2_run_1:
    del sc_5_mtnc_2_run_1[ 'failure']

keys_list = list(sc_5_mtnc_2_run_1.keys())
values_list = list(sc_5_mtnc_2_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run1 Time for Scale5')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_5_mtnc_2_run_2 = {'DF_CS_delete.py': 0.016233205795288086, 'DF_I_delete.py': 0.02187204360961914, 'DF_SS_delete.py': 0.025159358978271484, 'DF_WS_delete.py': 0.017705917358398438, 'failure': 20.004978895187378, 'LF_CR_insert.py': 0.04028177261352539, 'LF_CS_insert.py': 0.04060220718383789, 'LF_I_insert.py': 0.1344621181488037, 'LF_SR_insert.py': 0.016688108444213867, 'LF_SS_insert.py': 0.03182387351989746, 'LF_WR_insert.py': 0.017214059829711914, 'LF_WS_insert.py': 0.03217506408691406, 'test_linhan.py': 0.028872966766357422}
if  'failure' in sc_5_mtnc_2_run_2:
    del sc_5_mtnc_2_run_2[ 'failure']

keys_list = list(sc_5_mtnc_2_run_2.keys())
values_list = list(sc_5_mtnc_2_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run2 Time for Scale5')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_7_mtnc_1_run_1 = {'DF_CS_delete.py': 0.09805893898010254, 'DF_I_delete.py': 0.025133848190307617, 'DF_SS_delete.py': 0.13925719261169434, 'DF_WS_delete.py': 0.07550406455993652, 'failure': 20.005558967590332, 'LF_CR_insert.py': 0.04243302345275879, 'LF_CS_insert.py': 0.046029090881347656, 'LF_I_insert.py': 0.15583205223083496, 'LF_SR_insert.py': 0.02308511734008789, 'LF_SS_insert.py': 0.0424199104309082, 'LF_WR_insert.py': 0.01950526237487793, 'LF_WS_insert.py': 0.03815007209777832, 'test_linhan.py': 0.026759862899780273}
if  'failure' in sc_7_mtnc_1_run_1:
    del sc_7_mtnc_1_run_1[ 'failure']

keys_list = list(sc_7_mtnc_1_run_1.keys())
values_list = list(sc_7_mtnc_1_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run1 Time for Scale7')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_7_mtnc_1_run_2 = {'DF_CS_delete.py': 0.039090871810913086, 'DF_I_delete.py': 0.023633241653442383, 'DF_SS_delete.py': 0.029339313507080078, 'DF_WS_delete.py': 0.01833796501159668, 'failure': 20.003472805023193, 'LF_CR_insert.py': 0.026836395263671875, 'LF_CS_insert.py': 0.034497737884521484, 'LF_I_insert.py': 0.1382143497467041, 'LF_SR_insert.py': 0.017912864685058594, 'LF_SS_insert.py': 0.032080888748168945, 'LF_WR_insert.py': 0.016908645629882812, 'LF_WS_insert.py': 0.030365943908691406, 'test_linhan.py': 0.028820276260375977}
if  'failure' in sc_7_mtnc_1_run_2:
    del sc_7_mtnc_1_run_2[ 'failure']

keys_list = list(sc_7_mtnc_1_run_2.keys())
values_list = list(sc_7_mtnc_1_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance1 Run2 Time for Scale7')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_7_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04520297050476074, 'DF_I_delete.py': 0.023006200790405273, 'DF_SS_delete.py': 0.02570509910583496, 'DF_WS_delete.py': 0.017008066177368164, 'failure': 20.005526065826416, 'LF_CR_insert.py': 0.05068206787109375, 'LF_CS_insert.py': 0.057804107666015625, 'LF_I_insert.py': 0.15722393989562988, 'LF_SR_insert.py': 0.025101184844970703, 'LF_SS_insert.py': 0.057779788970947266, 'LF_WR_insert.py': 0.01852703094482422, 'LF_WS_insert.py': 0.045661211013793945, 'test_linhan.py': 0.028923988342285156}
if  'failure' in sc_7_mtnc_2_run_1:
    del sc_7_mtnc_2_run_1[ 'failure']

keys_list = list(sc_7_mtnc_2_run_1.keys())
values_list = list(sc_7_mtnc_2_run_1.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run1 Time for Scale7')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sc_7_mtnc_2_run_2 = {'DF_CS_delete.py': 0.01585221290588379, 'DF_I_delete.py': 0.022324085235595703, 'DF_SS_delete.py': 0.026610851287841797, 'DF_WS_delete.py': 0.01776289939880371, 'failure': 20.0056791305542, 'LF_CR_insert.py': 0.04098010063171387, 'LF_CS_insert.py': 0.03574085235595703, 'LF_I_insert.py': 0.14910507202148438, 'LF_SR_insert.py': 0.017587900161743164, 'LF_SS_insert.py': 0.031022071838378906, 'LF_WR_insert.py': 0.016024112701416016, 'LF_WS_insert.py': 0.03121185302734375, 'test_linhan.py': 0.026308774948120117}
if  'failure' in sc_7_mtnc_2_run_2:
    del sc_7_mtnc_2_run_2[ 'failure']

keys_list = list(sc_7_mtnc_2_run_2.keys())
values_list = list(sc_7_mtnc_2_run_2.values())


# Create the bar chart
plt.figure(figsize=(25, 15))
plt.bar(keys_list, values_list)

# Add a title and labels to the axes
plt.title('Maintenance2 Run2 Time for Scale7')
plt.xlabel('Python File')
plt.ylabel('Execution Time(Seconds)')

# Display the chart
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 标签和数据
sc_1_mtnc_1 = 42.83546280860901
sc_1_mtnc_2 = 43.04737305641174

sc_3_mtnc_1 = 41.28210377693176
sc_3_mtnc_2 = 41.256858110427856

sc_5_mtnc_1 = 41.62815499305725
sc_5_mtnc_2 = 41.27326989173889

sc_7_mtnc_1 = 41.502182722091675
sc_7_mtnc_2 = 41.260470151901245


labels = ['1', '3', '5', '7']
data1 = [sc_1_mtnc_1, sc_3_mtnc_1, sc_5_mtnc_1, sc_7_mtnc_1]
data1 = [round(num, 2) for num in data1]
data2 = [sc_1_mtnc_2, sc_3_mtnc_2, sc_5_mtnc_2, sc_7_mtnc_2]
data2 = [round(num, 2) for num in data2]


x = np.arange(len(labels))  
width = 0.35  

# 设置图像大小
#plt.figure(figsize=(10, 10))  # 设置宽为10英寸和高为5英寸
fig, ax = plt.subplots(figsize=(10, 6)) 
# 设置y轴的范围
ax.set_ylim(0, 55)  # 设置范围从0到60

data1 = ax.bar(x - width/2, data1, width, label='Maintenance 1')
data2 = ax.bar(x + width/2, data2, width, label='Maintenance 2')


def autolabel(rects, ax,fontsize=10):
    """给柱子上方添加标签"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
# 调用autolabel函数给每个柱子添加标签
autolabel(data1, ax,fontsize=5)
autolabel(data2, ax,fontsize=5)


ax.set_xlabel('Scale Factors')
ax.set_ylabel('Execution Time(Seconds)')
ax.set_title('MaintenanceTest')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 示例数据
#categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
#values1 = [3, 4, 7, 6, 1]
#values2 = [5, 2, 8, 4, 9]
#values3 = [4, 3, 5, 7, 8]
#values4 = [2, 5, 6, 3, 7]



#op_sc_1 = {'query_23b.sql': [0.1454000473022461, 0.0012049674987792969], 'query_22.sql': [0.05560803413391113, 0.00033473968505859375], 'query_23.sql': [0.12807202339172363, 0.0014920234680175781], 'query_14b.sql': [0.0021698474884033203, 0.002090930938720703], 'query_47.sql': [0.1083531379699707, 0.0008959770202636719], 'query_4.sql': [0.002960205078125, 0.0028228759765625], 'query_95.sql': [0.1328871250152588, 0.0005030632019042969], 'query_57.sql': [0.05723404884338379, 0.0008902549743652344], 'query_67.sql': [0.0003516674041748047, 0.0002951622009277344], 'query_64.sql': [0.0013799667358398438, 0.0013697147369384766], 'query_11.sql': [0.0010809898376464844, 0.001071929931640625], 'query_14.sql': [0.0013837814331054688, 0.0014119148254394531]}
Keys_List=['23b', '22', '23', '14b', '47', '4', '95', '57', '67', '11', '14']

List_1_origin= [0.1454000473022461, 0.05560803413391113, 0.12807202339172363, 0.0021698474884033203, 0.1083531379699707, 0.002960205078125, 0.1328871250152588, 0.05723404884338379, 0.0003516674041748047, 0.0010809898376464844, 0.0013837814331054688]
List_1_origin = [round(num, 3) for num in List_1_origin]
#List_1_optimization= [0.0012049674987792969, 0.00033473968505859375, 0.0014920234680175781, 0.002090930938720703, 0.0008959770202636719, 0.0028228759765625, 0.0005030632019042969, 0.0008902549743652344, 0.0002951622009277344, 0.001071929931640625, 0.0014119148254394531]

List_3_origin= [0.3837320804595947, 0.10355687141418457, 0.29953932762145996, 0.002067089080810547, 0.1997077465057373, 0.0030968189239501953, 0.48744726181030273, 0.1082148551940918, 0.00034999847412109375, 0.0013322830200195312, 0.0014312267303466797]
List_3_origin = [round(num, 3) for num in List_3_origin]

#List_3_optimization= [0.0010609626770019531, 0.0002620220184326172, 0.0013217926025390625, 0.0018680095672607422, 0.0008931159973144531, 0.0028448104858398438, 0.0005521774291992188, 0.0010118484497070312, 0.00029206275939941406, 0.0011878013610839844, 0.0014159679412841797]

List_5_origin= [0.5229837894439697, 0.19035005569458008, 0.41120100021362305, 1.1839189529418945, 0.2459421157836914, 1.8013417720794678, 0.7921462059020996, 0.15244817733764648, 2.4549028873443604, 1.2277090549468994, 1.0674750804901123]
List_5_origin = [round(num, 3) for num in List_5_origin]
#List_5_optimization= [0.0011229515075683594, 0.00028204917907714844, 0.0012040138244628906, 0.002446889877319336, 0.0010590553283691406, 0.0029020309448242188, 0.0007989406585693359, 0.001035928726196289, 0.0004570484161376953, 0.0013668537139892578, 0.0017521381378173828]


List_7_origin= [0.7302348613739014, 0.280850887298584, 0.5741119384765625, 1.6620166301727295, 0.2947700023651123, 2.504948377609253, 1.0165119171142578, 0.1818399429321289, 3.4762377738952637, 1.674799919128418, 1.5553631782531738]
List_7_origin = [round(num, 3) for num in List_7_origin]
#List_7_optimization= [0.0011439323425292969, 0.0002410411834716797, 0.0012350082397460938, 0.0021669864654541016, 0.0011582374572753906, 0.0028951168060302734, 0.0007801055908203125, 0.0010149478912353516, 0.0005869865417480469, 0.0014121532440185547, 0.0016379356384277344]


# 深色到浅色的颜色阶梯
colors = ['orange', 'green', 'mediumblue', 'brown']

fig, ax = plt.subplots(figsize=(8, 12))

# 绘制每一组数据。先绘制最大值，然后是次大值，以此类推。
bars1 = ax.barh(Keys_List, [max(List_1_origin, List_3_origin, List_5_origin, List_7_origin) for List_1_origin, List_3_origin, List_5_origin, List_7_origin in zip(List_1_origin, List_3_origin, List_5_origin, List_7_origin)], color=colors[3])
bars2 = ax.barh(Keys_List, [sorted([List_1_origin, List_3_origin, List_5_origin, List_7_origin])[-2] for List_1_origin, List_3_origin, List_5_origin, List_7_origin in zip(List_1_origin, List_3_origin, List_5_origin, List_7_origin)], color=colors[2])
bars3 = ax.barh(Keys_List, [sorted([List_1_origin, List_3_origin, List_5_origin, List_7_origin])[-3] for List_1_origin, List_3_origin, List_5_origin, List_7_origin in zip(List_1_origin, List_3_origin, List_5_origin, List_7_origin)], color=colors[1])
bars4 = ax.barh(Keys_List, [min(List_1_origin, List_3_origin, List_5_origin, List_7_origin) for List_1_origin, List_3_origin, List_5_origin, List_7_origin in zip(List_1_origin, List_3_origin, List_5_origin, List_7_origin)], color=colors[0])


#bars1 = ax.barh(categories, [max(v1, v2, v3, v4) for v1, v2, v3, v4 in zip(values1, values2, values3, values4)], color=colors[3])
#bars2 = ax.barh(categories, [sorted([v1, v2, v3, v4])[-2] for v1, v2, v3, v4 in zip(values1, values2, values3, values4)], color=colors[2])
#bars3 = ax.barh(categories, [sorted([v1, v2, v3, v4])[-3] for v1, v2, v3, v4 in zip(values1, values2, values3, values4)], color=colors[1])
#bars4 = ax.barh(categories, [min(v1, v2, v3, v4) for v1, v2, v3, v4 in zip(values1, values2, values3, values4)], color=colors[0])

# 添加标签的函数
def autolabel(bars, color):
    for bar in bars:
        width = bar.get_width()
        ax.annotate('{}'.format(width),
                    xy=(width, bar.get_y() + bar.get_height() / 2),
                    xytext=(5, 0),  # 5 points horizontal offset
                    textcoords="offset points",
                    ha='left', va='center',
                    color=color)

# 为每个柱子添加标签
autolabel(bars1, 'black')
autolabel(bars2, 'white')
autolabel(bars3, 'white')
autolabel(bars4, 'white')

# 设置标题和标签
ax.set_xlabel('Execution Time(Seconds)')
ax.set_title('Origin')
ax.legend([bars1[0], bars2[0], bars3[0], bars4[0]], ['7GB', '5GB', '3GB', '1GB'])

plt.tight_layout()
plt.show()

# %%
# 示例字典

sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
if  'failure' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'test_linhan.py']

sc_1_mtnc_2_run_1 = {'DF_CS_delete.py': 0.07776284217834473, 'DF_I_delete.py': 0.45646095275878906, 'DF_SS_delete.py': 0.7255277633666992, 'DF_WS_delete.py': 0.23304486274719238, 'failure': 20.00579810142517, 'LF_CR_insert.py': 0.0344851016998291, 'LF_CS_insert.py': 0.03538203239440918, 'LF_I_insert.py': 0.14161896705627441, 'LF_SR_insert.py': 0.01501011848449707, 'LF_SS_insert.py': 0.023398160934448242, 'LF_WR_insert.py': 0.015402078628540039, 'LF_WS_insert.py': 0.02540111541748047, 'test_linhan.py': 0.028169870376586914}
if  'failure' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'test_linhan.py']
# 提取键和值
keys_list = list(sc_1_mtnc_1_run_1.keys())
values1_list = list(sc_1_mtnc_1_run_1.values())
values2_list = list(sc_1_mtnc_2_run_1.values())
#List_5_origin = [round(num, 3) for num in List_5_origin]

print("Keys:", keys_list)
print("Values:", values1_list)
print("Values:", values2_list)
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.0844879150390625, 0.013923883438110352, 0.9074771404266357, 0.27125000953674316, 0.04225301742553711, 0.042488813400268555, 0.1302320957183838, 0.016154766082763672, 0.034861087799072266, 0.01619100570678711, 0.03455495834350586]
# Values: [0.07776284217834473, 0.45646095275878906, 0.7255277633666992, 0.23304486274719238, 0.0344851016998291, 0.03538203239440918, 0.14161896705627441, 0.01501011848449707, 0.023398160934448242, 0.015402078628540039, 0.02540111541748047]

# %%
import matplotlib.pyplot as plt


# 示例字典

sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
if  'failure' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'test_linhan.py']

sc_1_mtnc_2_run_1 = {'DF_CS_delete.py': 0.07776284217834473, 'DF_I_delete.py': 0.45646095275878906, 'DF_SS_delete.py': 0.7255277633666992, 'DF_WS_delete.py': 0.23304486274719238, 'failure': 20.00579810142517, 'LF_CR_insert.py': 0.0344851016998291, 'LF_CS_insert.py': 0.03538203239440918, 'LF_I_insert.py': 0.14161896705627441, 'LF_SR_insert.py': 0.01501011848449707, 'LF_SS_insert.py': 0.023398160934448242, 'LF_WR_insert.py': 0.015402078628540039, 'LF_WS_insert.py': 0.02540111541748047, 'test_linhan.py': 0.028169870376586914}
if  'failure' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'test_linhan.py']
# 提取键和值
keys_list = list(sc_1_mtnc_1_run_1.keys())
values1_list = list(sc_1_mtnc_1_run_1.values())
values2_list = list(sc_1_mtnc_2_run_1.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values1_list)
print("Values:", values2_list)

# 示例数据
keys_list = list(sc_1_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.35
r1 = range(len(values1_list))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(12,6))

# 绘制条形
bars1 = plt.barh(r1, values1_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1')
bars2 = plt.barh(r2, values2_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values1_list), max(values2_list))
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.1, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.1, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance in Scale1')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.0844879150390625, 0.013923883438110352, 0.9074771404266357, 0.27125000953674316, 0.04225301742553711, 0.042488813400268555, 0.1302320957183838, 0.016154766082763672, 0.034861087799072266, 0.01619100570678711, 0.03455495834350586]
# Values: [0.07776284217834473, 0.45646095275878906, 0.7255277633666992, 0.23304486274719238, 0.0344851016998291, 0.03538203239440918, 0.14161896705627441, 0.01501011848449707, 0.023398160934448242, 0.015402078628540039, 0.02540111541748047]

# %%
import matplotlib.pyplot as plt


# 示例字典

sc_3_mtnc_1_run_1 = {'DF_CS_delete.py': 0.11405229568481445, 'DF_I_delete.py': 0.02390289306640625, 'DF_SS_delete.py': 0.18929219245910645, 'DF_WS_delete.py': 0.09778285026550293, 'failure': 20.00570321083069, 'LF_CR_insert.py': 0.044631004333496094, 'LF_CS_insert.py': 0.04781532287597656, 'LF_I_insert.py': 0.14746904373168945, 'LF_SR_insert.py': 0.02198314666748047, 'LF_SS_insert.py': 0.04401206970214844, 'LF_WR_insert.py': 0.018975019454956055, 'LF_WS_insert.py': 0.036560773849487305, 'test_linhan.py': 0.02629709243774414}
if  'failure' in sc_3_mtnc_1_run_1:
    del sc_3_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_3_mtnc_1_run_1:
    del sc_3_mtnc_1_run_1[ 'test_linhan.py']

sc_3_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04625272750854492, 'DF_I_delete.py': 0.02321791648864746, 'DF_SS_delete.py': 0.027719974517822266, 'DF_WS_delete.py': 0.018450260162353516, 'failure': 20.00582218170166, 'LF_CR_insert.py': 0.04858875274658203, 'LF_CS_insert.py': 0.05615115165710449, 'LF_I_insert.py': 0.14717602729797363, 'LF_SR_insert.py': 0.025307893753051758, 'LF_SS_insert.py': 0.05813288688659668, 'LF_WR_insert.py': 0.017707109451293945, 'LF_WS_insert.py': 0.046903133392333984, 'test_linhan.py': 0.028213977813720703}
if  'failure' in sc_3_mtnc_2_run_1:
    del sc_3_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_3_mtnc_2_run_1:
    del sc_3_mtnc_2_run_1[ 'test_linhan.py']
# 提取键和值
keys_list = list(sc_3_mtnc_1_run_1.keys())
values1_list = list(sc_3_mtnc_1_run_1.values())
values2_list = list(sc_3_mtnc_2_run_1.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values1_list)
print("Values:", values2_list)

# 示例数据
keys_list = list(sc_3_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.35
r1 = range(len(values1_list))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(12,6))

# 绘制条形
bars1 = plt.barh(r1, values1_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1')
bars2 = plt.barh(r2, values2_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values1_list), max(values2_list))
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance in Scale3')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.11405229568481445, 0.02390289306640625, 0.18929219245910645, 0.09778285026550293, 0.044631004333496094, 0.04781532287597656, 0.14746904373168945, 0.02198314666748047, 0.04401206970214844, 0.018975019454956055, 0.036560773849487305]
# Values: [0.04625272750854492, 0.02321791648864746, 0.027719974517822266, 0.018450260162353516, 0.04858875274658203, 0.05615115165710449, 0.14717602729797363, 0.025307893753051758, 0.05813288688659668, 0.017707109451293945, 0.046903133392333984]

# %%
import matplotlib.pyplot as plt


# 示例字典

sc_5_mtnc_1_run_1 = {'DF_CS_delete.py': 0.10871601104736328, 'DF_I_delete.py': 0.03187394142150879, 'DF_SS_delete.py': 0.13074398040771484, 'DF_WS_delete.py': 0.09054207801818848, 'failure': 20.005099773406982, 'LF_CR_insert.py': 0.04679083824157715, 'LF_CS_insert.py': 0.0474088191986084, 'LF_I_insert.py': 0.16495203971862793, 'LF_SR_insert.py': 0.0230867862701416, 'LF_SS_insert.py': 0.048413991928100586, 'LF_WR_insert.py': 0.019726037979125977, 'LF_WS_insert.py': 0.03803396224975586, 'test_linhan.py': 0.026525020599365234}
if  'failure' in sc_5_mtnc_1_run_1:
    del sc_5_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_5_mtnc_1_run_1:
    del sc_5_mtnc_1_run_1[ 'test_linhan.py']

sc_5_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04702186584472656, 'DF_I_delete.py': 0.024369239807128906, 'DF_SS_delete.py': 0.02764582633972168, 'DF_WS_delete.py': 0.017188072204589844, 'failure': 20.005616903305054, 'LF_CR_insert.py': 0.049051761627197266, 'LF_CS_insert.py': 0.06269097328186035, 'LF_I_insert.py': 0.14451193809509277, 'LF_SR_insert.py': 0.0255429744720459, 'LF_SS_insert.py': 0.06828713417053223, 'LF_WR_insert.py': 0.0190432071685791, 'LF_WS_insert.py': 0.053540706634521484, 'test_linhan.py': 0.029045820236206055}
if  'failure' in sc_5_mtnc_2_run_1:
    del sc_5_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_5_mtnc_2_run_1:
    del sc_5_mtnc_2_run_1[ 'test_linhan.py']
# 提取键和值
keys_list = list(sc_5_mtnc_1_run_1.keys())
values1_list = list(sc_5_mtnc_1_run_1.values())
values2_list = list(sc_5_mtnc_2_run_1.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values1_list)
print("Values:", values2_list)

# 示例数据
keys_list = list(sc_5_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.35
r1 = range(len(values1_list))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(12,6))

# 绘制条形
bars1 = plt.barh(r1, values1_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1')
bars2 = plt.barh(r2, values2_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values1_list), max(values2_list))
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance in Scale5')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.10871601104736328, 0.03187394142150879, 0.13074398040771484, 0.09054207801818848, 0.04679083824157715, 0.0474088191986084, 0.16495203971862793, 0.0230867862701416, 0.048413991928100586, 0.019726037979125977, 0.03803396224975586]
# Values: [0.04702186584472656, 0.024369239807128906, 0.02764582633972168, 0.017188072204589844, 0.049051761627197266, 0.06269097328186035, 0.14451193809509277, 0.0255429744720459, 0.06828713417053223, 0.0190432071685791, 0.053540706634521484]

# %%
import matplotlib.pyplot as plt


# 示例字典

sc_7_mtnc_1_run_1 = {'DF_CS_delete.py': 0.09805893898010254, 'DF_I_delete.py': 0.025133848190307617, 'DF_SS_delete.py': 0.13925719261169434, 'DF_WS_delete.py': 0.07550406455993652, 'failure': 20.005558967590332, 'LF_CR_insert.py': 0.04243302345275879, 'LF_CS_insert.py': 0.046029090881347656, 'LF_I_insert.py': 0.15583205223083496, 'LF_SR_insert.py': 0.02308511734008789, 'LF_SS_insert.py': 0.0424199104309082, 'LF_WR_insert.py': 0.01950526237487793, 'LF_WS_insert.py': 0.03815007209777832, 'test_linhan.py': 0.026759862899780273}
if  'failure' in sc_7_mtnc_1_run_1:
    del sc_7_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_7_mtnc_1_run_1:
    del sc_7_mtnc_1_run_1[ 'test_linhan.py']

sc_7_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04520297050476074, 'DF_I_delete.py': 0.023006200790405273, 'DF_SS_delete.py': 0.02570509910583496, 'DF_WS_delete.py': 0.017008066177368164, 'failure': 20.005526065826416, 'LF_CR_insert.py': 0.05068206787109375, 'LF_CS_insert.py': 0.057804107666015625, 'LF_I_insert.py': 0.15722393989562988, 'LF_SR_insert.py': 0.025101184844970703, 'LF_SS_insert.py': 0.057779788970947266, 'LF_WR_insert.py': 0.01852703094482422, 'LF_WS_insert.py': 0.045661211013793945, 'test_linhan.py': 0.028923988342285156}
if  'failure' in sc_7_mtnc_2_run_1:
    del sc_7_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_7_mtnc_2_run_1:
    del sc_7_mtnc_2_run_1[ 'test_linhan.py']
# 提取键和值
keys_list = list(sc_7_mtnc_1_run_1.keys())
values1_list = list(sc_7_mtnc_1_run_1.values())
values2_list = list(sc_7_mtnc_2_run_1.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values1_list)
print("Values:", values2_list)

# 示例数据
keys_list = list(sc_7_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.35
r1 = range(len(values1_list))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(12,6))

# 绘制条形
bars1 = plt.barh(r1, values1_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1')
bars2 = plt.barh(r2, values2_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values1_list), max(values2_list))
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance in Scale7')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.09805893898010254, 0.025133848190307617, 0.13925719261169434, 0.07550406455993652, 0.04243302345275879, 0.046029090881347656, 0.15583205223083496, 0.02308511734008789, 0.0424199104309082, 0.01950526237487793, 0.03815007209777832]
# Values: [0.04520297050476074, 0.023006200790405273, 0.02570509910583496, 0.017008066177368164, 0.05068206787109375, 0.057804107666015625, 0.15722393989562988, 0.025101184844970703, 0.057779788970947266, 0.01852703094482422, 0.045661211013793945]

# %%
import matplotlib.pyplot as plt


# 示例字典

sc_1_mtnc_1_run_1 = {'DF_CS_delete.py': 0.0844879150390625, 'DF_I_delete.py': 0.013923883438110352, 'DF_SS_delete.py': 0.9074771404266357, 'DF_WS_delete.py': 0.27125000953674316, 'failure': 20.00594997406006, 'LF_CR_insert.py': 0.04225301742553711, 'LF_CS_insert.py': 0.042488813400268555, 'LF_I_insert.py': 0.1302320957183838, 'LF_SR_insert.py': 0.016154766082763672, 'LF_SS_insert.py': 0.034861087799072266, 'LF_WR_insert.py': 0.01619100570678711, 'LF_WS_insert.py': 0.03455495834350586, 'test_linhan.py': 0.02875494956970215}
if  'failure' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_1_run_1:
    del sc_1_mtnc_1_run_1[ 'test_linhan.py']

sc_1_mtnc_1_run_2 = {'DF_CS_delete.py': 0.031365156173706055, 'DF_I_delete.py': 0.011495828628540039, 'DF_SS_delete.py': 0.607820987701416, 'DF_WS_delete.py': 0.19784069061279297, 'failure': 20.003587245941162, 'LF_CR_insert.py': 0.03851795196533203, 'LF_CS_insert.py': 0.033492088317871094, 'LF_I_insert.py': 0.14211392402648926, 'LF_SR_insert.py': 0.015489816665649414, 'LF_SS_insert.py': 0.021422863006591797, 'LF_WR_insert.py': 0.014980077743530273, 'LF_WS_insert.py': 0.02646017074584961, 'test_linhan.py': 0.03458380699157715}    
if  'failure' in sc_1_mtnc_1_run_2:
    del sc_1_mtnc_1_run_2[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_1_run_2:
    del sc_1_mtnc_1_run_2[ 'test_linhan.py']

sc_1_mtnc_2_run_1 = {'DF_CS_delete.py': 0.07776284217834473, 'DF_I_delete.py': 0.45646095275878906, 'DF_SS_delete.py': 0.7255277633666992, 'DF_WS_delete.py': 0.23304486274719238, 'failure': 20.00579810142517, 'LF_CR_insert.py': 0.0344851016998291, 'LF_CS_insert.py': 0.03538203239440918, 'LF_I_insert.py': 0.14161896705627441, 'LF_SR_insert.py': 0.01501011848449707, 'LF_SS_insert.py': 0.023398160934448242, 'LF_WR_insert.py': 0.015402078628540039, 'LF_WS_insert.py': 0.02540111541748047, 'test_linhan.py': 0.028169870376586914}
if  'failure' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_2_run_1:
    del sc_1_mtnc_2_run_1[ 'test_linhan.py']
    
sc_1_mtnc_2_run_2 = {'DF_CS_delete.py': 0.030813217163085938, 'DF_I_delete.py': 0.010808944702148438, 'DF_SS_delete.py': 0.6375858783721924, 'DF_WS_delete.py': 0.19521093368530273, 'failure': 20.00576901435852, 'LF_CR_insert.py': 0.03650808334350586, 'LF_CS_insert.py': 0.03334188461303711, 'LF_I_insert.py': 0.14561891555786133, 'LF_SR_insert.py': 0.01435708999633789, 'LF_SS_insert.py': 0.022155046463012695, 'LF_WR_insert.py': 0.014965057373046875, 'LF_WS_insert.py': 0.029603004455566406, 'test_linhan.py': 0.02772212028503418}  
if  'failure' in sc_1_mtnc_2_run_2:
    del sc_1_mtnc_2_run_2[ 'failure']
if  'test_linhan.py' in sc_1_mtnc_2_run_2:
    del sc_1_mtnc_2_run_2[ 'test_linhan.py']
    

# 提取键和值
keys_list = list(sc_1_mtnc_1_run_1.keys())
values11_list = list(sc_1_mtnc_1_run_1.values())
values12_list = list(sc_1_mtnc_1_run_2.values())
values21_list = list(sc_1_mtnc_2_run_1.values())
values22_list = list(sc_1_mtnc_2_run_2.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values11_list)
print("Values:", values12_list)
print("Values:", values21_list)
print("Values:", values22_list)
# 示例数据
keys_list = list(sc_1_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.2
r1 = range(len(values11_list))
r2 = [x + barWidth for x in r1]

r3 = [x + barWidth*2 for x in r1]
r4 = [x + barWidth*3 for x in r1]

plt.figure(figsize=(10,15))

# 绘制条形
bars1 = plt.barh(r1, values11_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run1')
bars2 = plt.barh(r2, values12_list, color='darkblue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run2')
bars3 = plt.barh(r3, values21_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2 Run1')
bars4 = plt.barh(r4, values22_list, color='#8B0000', height=barWidth, edgecolor='grey', label='Maintenance 2 Run2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values11_list), max(values12_list),max(values21_list),max(values22_list),)
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.1, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.1, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

    
for bar in bars3:
    yval = bar.get_width()
    plt.text(yval + 0.1, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
for bar in bars4:
    yval = bar.get_width()
    plt.text(yval + 0.1, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance and Two Run in Scale1')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.0844879150390625, 0.013923883438110352, 0.9074771404266357, 0.27125000953674316, 0.04225301742553711, 0.042488813400268555, 0.1302320957183838, 0.016154766082763672, 0.034861087799072266, 0.01619100570678711, 0.03455495834350586]
# Values: [0.031365156173706055, 0.011495828628540039, 0.607820987701416, 0.19784069061279297, 0.03851795196533203, 0.033492088317871094, 0.14211392402648926, 0.015489816665649414, 0.021422863006591797, 0.014980077743530273, 0.02646017074584961]
# Values: [0.07776284217834473, 0.45646095275878906, 0.7255277633666992, 0.23304486274719238, 0.0344851016998291, 0.03538203239440918, 0.14161896705627441, 0.01501011848449707, 0.023398160934448242, 0.015402078628540039, 0.02540111541748047]
# ...

# %%
import matplotlib.pyplot as plt


# 示例字典
sc_3_mtnc_1_run_1 = {'DF_CS_delete.py': 0.11405229568481445, 'DF_I_delete.py': 0.02390289306640625, 'DF_SS_delete.py': 0.18929219245910645, 'DF_WS_delete.py': 0.09778285026550293, 'failure': 20.00570321083069, 'LF_CR_insert.py': 0.044631004333496094, 'LF_CS_insert.py': 0.04781532287597656, 'LF_I_insert.py': 0.14746904373168945, 'LF_SR_insert.py': 0.02198314666748047, 'LF_SS_insert.py': 0.04401206970214844, 'LF_WR_insert.py': 0.018975019454956055, 'LF_WS_insert.py': 0.036560773849487305, 'test_linhan.py': 0.02629709243774414}
if  'failure' in sc_3_mtnc_1_run_1:
    del sc_3_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_3_mtnc_1_run_1:
    del sc_3_mtnc_1_run_1[ 'test_linhan.py']

sc_3_mtnc_1_run_2 = {'DF_CS_delete.py': 0.0364532470703125, 'DF_I_delete.py': 0.022266149520874023, 'DF_SS_delete.py': 0.028244972229003906, 'DF_WS_delete.py': 0.01862335205078125, 'failure': 20.005665063858032, 'LF_CR_insert.py': 0.04490399360656738, 'LF_CS_insert.py': 0.03934216499328613, 'LF_I_insert.py': 0.14059996604919434, 'LF_SR_insert.py': 0.018616199493408203, 'LF_SS_insert.py': 0.030556917190551758, 'LF_WR_insert.py': 0.017981767654418945, 'LF_WS_insert.py': 0.031950950622558594, 'test_linhan.py': 0.028422117233276367}
if  'failure' in sc_3_mtnc_1_run_2:
    del sc_3_mtnc_1_run_2[ 'failure']
if  'test_linhan.py' in sc_3_mtnc_1_run_2:
    del sc_3_mtnc_1_run_2[ 'test_linhan.py']

sc_3_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04625272750854492, 'DF_I_delete.py': 0.02321791648864746, 'DF_SS_delete.py': 0.027719974517822266, 'DF_WS_delete.py': 0.018450260162353516, 'failure': 20.00582218170166, 'LF_CR_insert.py': 0.04858875274658203, 'LF_CS_insert.py': 0.05615115165710449, 'LF_I_insert.py': 0.14717602729797363, 'LF_SR_insert.py': 0.025307893753051758, 'LF_SS_insert.py': 0.05813288688659668, 'LF_WR_insert.py': 0.017707109451293945, 'LF_WS_insert.py': 0.046903133392333984, 'test_linhan.py': 0.028213977813720703}
if  'failure' in sc_3_mtnc_2_run_1:
    del sc_3_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_3_mtnc_2_run_1:
    del sc_3_mtnc_2_run_1[ 'test_linhan.py']
    
sc_3_mtnc_2_run_2 = {'DF_CS_delete.py': 0.01627492904663086, 'DF_I_delete.py': 0.022578001022338867, 'DF_SS_delete.py': 0.025724172592163086, 'DF_WS_delete.py': 0.016866683959960938, 'failure': 20.005707025527954, 'LF_CR_insert.py': 0.04039788246154785, 'LF_CS_insert.py': 0.03652620315551758, 'LF_I_insert.py': 0.15407395362854004, 'LF_SR_insert.py': 0.016583919525146484, 'LF_SS_insert.py': 0.0316929817199707, 'LF_WR_insert.py': 0.01673412322998047, 'LF_WS_insert.py': 0.032000064849853516, 'test_linhan.py': 0.02860283851623535}
if  'failure' in sc_3_mtnc_2_run_2:
    del sc_3_mtnc_2_run_2[ 'failure']
if  'test_linhan.py' in sc_3_mtnc_2_run_2:
    del sc_3_mtnc_2_run_2[ 'test_linhan.py']
    

# 提取键和值
keys_list = list(sc_3_mtnc_1_run_1.keys())
values11_list = list(sc_3_mtnc_1_run_1.values())
values12_list = list(sc_3_mtnc_1_run_2.values())
values21_list = list(sc_3_mtnc_2_run_1.values())
values22_list = list(sc_3_mtnc_2_run_2.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values11_list)
print("Values:", values12_list)
print("Values:", values21_list)
print("Values:", values22_list)
# 示例数据
keys_list = list(sc_3_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.2
r1 = range(len(values11_list))
r2 = [x + barWidth for x in r1]

r3 = [x + barWidth*2 for x in r1]
r4 = [x + barWidth*3 for x in r1]

plt.figure(figsize=(10,15))

# 绘制条形
bars1 = plt.barh(r1, values11_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run1')
bars2 = plt.barh(r2, values12_list, color='darkblue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run2')
bars3 = plt.barh(r3, values21_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2 Run1')
bars4 = plt.barh(r4, values22_list, color='#8B0000', height=barWidth, edgecolor='grey', label='Maintenance 2 Run2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values11_list), max(values12_list),max(values21_list),max(values22_list),)
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.05, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

    
for bar in bars3:
    yval = bar.get_width()
    plt.text(yval + 0.05, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
for bar in bars4:
    yval = bar.get_width()
    plt.text(yval + 0.05, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance and Two Run in Scale3')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.11405229568481445, 0.02390289306640625, 0.18929219245910645, 0.09778285026550293, 0.044631004333496094, 0.04781532287597656, 0.14746904373168945, 0.02198314666748047, 0.04401206970214844, 0.018975019454956055, 0.036560773849487305]
# Values: [0.0364532470703125, 0.022266149520874023, 0.028244972229003906, 0.01862335205078125, 0.04490399360656738, 0.03934216499328613, 0.14059996604919434, 0.018616199493408203, 0.030556917190551758, 0.017981767654418945, 0.031950950622558594]
# Values: [0.04625272750854492, 0.02321791648864746, 0.027719974517822266, 0.018450260162353516, 0.04858875274658203, 0.05615115165710449, 0.14717602729797363, 0.025307893753051758, 0.05813288688659668, 0.017707109451293945, 0.046903133392333984]
# ...

# %%
import matplotlib.pyplot as plt


# 示例字典
sc_5_mtnc_1_run_1 = {'DF_CS_delete.py': 0.10871601104736328, 'DF_I_delete.py': 0.03187394142150879, 'DF_SS_delete.py': 0.13074398040771484, 'DF_WS_delete.py': 0.09054207801818848, 'failure': 20.005099773406982, 'LF_CR_insert.py': 0.04679083824157715, 'LF_CS_insert.py': 0.0474088191986084, 'LF_I_insert.py': 0.16495203971862793, 'LF_SR_insert.py': 0.0230867862701416, 'LF_SS_insert.py': 0.048413991928100586, 'LF_WR_insert.py': 0.019726037979125977, 'LF_WS_insert.py': 0.03803396224975586, 'test_linhan.py': 0.026525020599365234}
if  'failure' in sc_5_mtnc_1_run_1:
    del sc_5_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_5_mtnc_1_run_1:
    del sc_5_mtnc_1_run_1[ 'test_linhan.py']

sc_5_mtnc_1_run_2 = {'DF_CS_delete.py': 0.04250502586364746, 'DF_I_delete.py': 0.024409770965576172, 'DF_SS_delete.py': 0.03317975997924805, 'DF_WS_delete.py': 0.022706985473632812, 'failure': 20.00553297996521, 'LF_CR_insert.py': 0.04375815391540527, 'LF_CS_insert.py': 0.03802180290222168, 'LF_I_insert.py': 0.1459507942199707, 'LF_SR_insert.py': 0.018959999084472656, 'LF_SS_insert.py': 0.03332209587097168, 'LF_WR_insert.py': 0.017785072326660156, 'LF_WS_insert.py': 0.03195786476135254, 'test_linhan.py': 0.027806997299194336}
if  'failure' in sc_5_mtnc_1_run_2:
    del sc_5_mtnc_1_run_2[ 'failure']
if  'test_linhan.py' in sc_5_mtnc_1_run_2:
    del sc_5_mtnc_1_run_2[ 'test_linhan.py']

sc_5_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04702186584472656, 'DF_I_delete.py': 0.024369239807128906, 'DF_SS_delete.py': 0.02764582633972168, 'DF_WS_delete.py': 0.017188072204589844, 'failure': 20.005616903305054, 'LF_CR_insert.py': 0.049051761627197266, 'LF_CS_insert.py': 0.06269097328186035, 'LF_I_insert.py': 0.14451193809509277, 'LF_SR_insert.py': 0.0255429744720459, 'LF_SS_insert.py': 0.06828713417053223, 'LF_WR_insert.py': 0.0190432071685791, 'LF_WS_insert.py': 0.053540706634521484, 'test_linhan.py': 0.029045820236206055}
if  'failure' in sc_5_mtnc_2_run_1:
    del sc_5_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_5_mtnc_2_run_1:
    del sc_5_mtnc_2_run_1[ 'test_linhan.py']
    
sc_5_mtnc_2_run_2 = {'DF_CS_delete.py': 0.016233205795288086, 'DF_I_delete.py': 0.02187204360961914, 'DF_SS_delete.py': 0.025159358978271484, 'DF_WS_delete.py': 0.017705917358398438, 'failure': 20.004978895187378, 'LF_CR_insert.py': 0.04028177261352539, 'LF_CS_insert.py': 0.04060220718383789, 'LF_I_insert.py': 0.1344621181488037, 'LF_SR_insert.py': 0.016688108444213867, 'LF_SS_insert.py': 0.03182387351989746, 'LF_WR_insert.py': 0.017214059829711914, 'LF_WS_insert.py': 0.03217506408691406, 'test_linhan.py': 0.028872966766357422}
if  'failure' in sc_5_mtnc_2_run_2:
    del sc_5_mtnc_2_run_2[ 'failure']
if  'test_linhan.py' in sc_5_mtnc_2_run_2:
    del sc_5_mtnc_2_run_2[ 'test_linhan.py']
    

# 提取键和值
keys_list = list(sc_5_mtnc_1_run_1.keys())
values11_list = list(sc_5_mtnc_1_run_1.values())
values12_list = list(sc_5_mtnc_1_run_2.values())
values21_list = list(sc_5_mtnc_2_run_1.values())
values22_list = list(sc_5_mtnc_2_run_2.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values11_list)
print("Values:", values12_list)
print("Values:", values21_list)
print("Values:", values22_list)
# 示例数据
keys_list = list(sc_5_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.2
r1 = range(len(values11_list))
r2 = [x + barWidth for x in r1]

r3 = [x + barWidth*2 for x in r1]
r4 = [x + barWidth*3 for x in r1]

plt.figure(figsize=(10,15))

# 绘制条形
bars1 = plt.barh(r1, values11_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run1')
bars2 = plt.barh(r2, values12_list, color='darkblue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run2')
bars3 = plt.barh(r3, values21_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2 Run1')
bars4 = plt.barh(r4, values22_list, color='#8B0000', height=barWidth, edgecolor='grey', label='Maintenance 2 Run2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values11_list), max(values12_list),max(values21_list),max(values22_list),)
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

    
for bar in bars3:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
for bar in bars4:
    yval = bar.get_width()
    plt.text(yval + 0.05, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance and Two Run in Scale5')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.10871601104736328, 0.03187394142150879, 0.13074398040771484, 0.09054207801818848, 0.04679083824157715, 0.0474088191986084, 0.16495203971862793, 0.0230867862701416, 0.048413991928100586, 0.019726037979125977, 0.03803396224975586]
# Values: [0.04250502586364746, 0.024409770965576172, 0.03317975997924805, 0.022706985473632812, 0.04375815391540527, 0.03802180290222168, 0.1459507942199707, 0.018959999084472656, 0.03332209587097168, 0.017785072326660156, 0.03195786476135254]
# Values: [0.04702186584472656, 0.024369239807128906, 0.02764582633972168, 0.017188072204589844, 0.049051761627197266, 0.06269097328186035, 0.14451193809509277, 0.0255429744720459, 0.06828713417053223, 0.0190432071685791, 0.053540706634521484]
# ...

# %%
import matplotlib.pyplot as plt


# 示例字典
sc_7_mtnc_1_run_1 = {'DF_CS_delete.py': 0.09805893898010254, 'DF_I_delete.py': 0.025133848190307617, 'DF_SS_delete.py': 0.13925719261169434, 'DF_WS_delete.py': 0.07550406455993652, 'failure': 20.005558967590332, 'LF_CR_insert.py': 0.04243302345275879, 'LF_CS_insert.py': 0.046029090881347656, 'LF_I_insert.py': 0.15583205223083496, 'LF_SR_insert.py': 0.02308511734008789, 'LF_SS_insert.py': 0.0424199104309082, 'LF_WR_insert.py': 0.01950526237487793, 'LF_WS_insert.py': 0.03815007209777832, 'test_linhan.py': 0.026759862899780273}
if  'failure' in sc_7_mtnc_1_run_1:
    del sc_7_mtnc_1_run_1[ 'failure']
if  'test_linhan.py' in sc_7_mtnc_1_run_1:
    del sc_7_mtnc_1_run_1[ 'test_linhan.py']

sc_7_mtnc_1_run_2 = {'DF_CS_delete.py': 0.039090871810913086, 'DF_I_delete.py': 0.023633241653442383, 'DF_SS_delete.py': 0.029339313507080078, 'DF_WS_delete.py': 0.01833796501159668, 'failure': 20.003472805023193, 'LF_CR_insert.py': 0.026836395263671875, 'LF_CS_insert.py': 0.034497737884521484, 'LF_I_insert.py': 0.1382143497467041, 'LF_SR_insert.py': 0.017912864685058594, 'LF_SS_insert.py': 0.032080888748168945, 'LF_WR_insert.py': 0.016908645629882812, 'LF_WS_insert.py': 0.030365943908691406, 'test_linhan.py': 0.028820276260375977}
if  'failure' in sc_7_mtnc_1_run_2:
    del sc_7_mtnc_1_run_2[ 'failure']
if  'test_linhan.py' in sc_7_mtnc_1_run_2:
    del sc_7_mtnc_1_run_2[ 'test_linhan.py']

sc_7_mtnc_2_run_1 = {'DF_CS_delete.py': 0.04520297050476074, 'DF_I_delete.py': 0.023006200790405273, 'DF_SS_delete.py': 0.02570509910583496, 'DF_WS_delete.py': 0.017008066177368164, 'failure': 20.005526065826416, 'LF_CR_insert.py': 0.05068206787109375, 'LF_CS_insert.py': 0.057804107666015625, 'LF_I_insert.py': 0.15722393989562988, 'LF_SR_insert.py': 0.025101184844970703, 'LF_SS_insert.py': 0.057779788970947266, 'LF_WR_insert.py': 0.01852703094482422, 'LF_WS_insert.py': 0.045661211013793945, 'test_linhan.py': 0.028923988342285156}
if  'failure' in sc_7_mtnc_2_run_1:
    del sc_7_mtnc_2_run_1[ 'failure']
if  'test_linhan.py' in sc_7_mtnc_2_run_1:
    del sc_7_mtnc_2_run_1[ 'test_linhan.py']

    
sc_7_mtnc_2_run_2 = {'DF_CS_delete.py': 0.01585221290588379, 'DF_I_delete.py': 0.022324085235595703, 'DF_SS_delete.py': 0.026610851287841797, 'DF_WS_delete.py': 0.01776289939880371, 'failure': 20.0056791305542, 'LF_CR_insert.py': 0.04098010063171387, 'LF_CS_insert.py': 0.03574085235595703, 'LF_I_insert.py': 0.14910507202148438, 'LF_SR_insert.py': 0.017587900161743164, 'LF_SS_insert.py': 0.031022071838378906, 'LF_WR_insert.py': 0.016024112701416016, 'LF_WS_insert.py': 0.03121185302734375, 'test_linhan.py': 0.026308774948120117}
if  'failure' in sc_7_mtnc_2_run_2:
    del sc_7_mtnc_2_run_2[ 'failure']
if  'test_linhan.py' in sc_7_mtnc_2_run_2:
    del sc_7_mtnc_2_run_2[ 'test_linhan.py']
    

# 提取键和值
keys_list = list(sc_7_mtnc_1_run_1.keys())
values11_list = list(sc_7_mtnc_1_run_1.values())
values12_list = list(sc_7_mtnc_1_run_2.values())
values21_list = list(sc_7_mtnc_2_run_1.values())
values22_list = list(sc_7_mtnc_2_run_2.values())
#values1_list = [round(num, 3) for num in values1_list]

print("Keys:", keys_list)
print("Values:", values11_list)
print("Values:", values12_list)
print("Values:", values21_list)
print("Values:", values22_list)
# 示例数据
keys_list = list(sc_7_mtnc_1_run_1.keys())



# 定义位置和宽度
barWidth = 0.2
r1 = range(len(values11_list))
r2 = [x + barWidth for x in r1]

r3 = [x + barWidth*2 for x in r1]
r4 = [x + barWidth*3 for x in r1]

plt.figure(figsize=(10,15))

# 绘制条形
bars1 = plt.barh(r1, values11_list, color='blue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run1')
bars2 = plt.barh(r2, values12_list, color='darkblue', height=barWidth, edgecolor='grey', label='Maintenance 1 Run2')
bars3 = plt.barh(r3, values21_list, color='red', height=barWidth, edgecolor='grey', label='Maintenance 2 Run1')
bars4 = plt.barh(r4, values22_list, color='#8B0000', height=barWidth, edgecolor='grey', label='Maintenance 2 Run2')

# 设置X轴的范围以适应数据和标签
max_val = max(max(values11_list), max(values12_list),max(values21_list),max(values22_list),)
plt.xlim(0, max_val * 1.2)  # 给标签预留一些空间

# 标注具体数值
for bar in bars1:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

for bar in bars2:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')

    
for bar in bars3:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
for bar in bars4:
    yval = bar.get_width()
    plt.text(yval + 0.02, bar.get_y() + bar.get_height()/2, round(yval, 4), va='center', ha='left')
    
# 设置Y轴的标签
plt.yticks([r + barWidth for r in range(len(values1_list))], keys_list)
plt.xlabel('Execution Time(Seconds)')
plt.ylabel('Functions')
plt.title('Comparison of Two Maintenance and Two Run in Scale7')
plt.legend()

plt.show()
# Out:
# Keys: ['DF_CS_delete.py', 'DF_I_delete.py', 'DF_SS_delete.py', 'DF_WS_delete.py', 'LF_CR_insert.py', 'LF_CS_insert.py', 'LF_I_insert.py', 'LF_SR_insert.py', 'LF_SS_insert.py', 'LF_WR_insert.py', 'LF_WS_insert.py']
# Values: [0.09805893898010254, 0.025133848190307617, 0.13925719261169434, 0.07550406455993652, 0.04243302345275879, 0.046029090881347656, 0.15583205223083496, 0.02308511734008789, 0.0424199104309082, 0.01950526237487793, 0.03815007209777832]
# Values: [0.039090871810913086, 0.023633241653442383, 0.029339313507080078, 0.01833796501159668, 0.026836395263671875, 0.034497737884521484, 0.1382143497467041, 0.017912864685058594, 0.032080888748168945, 0.016908645629882812, 0.030365943908691406]
# Values: [0.04520297050476074, 0.023006200790405273, 0.02570509910583496, 0.017008066177368164, 0.05068206787109375, 0.057804107666015625, 0.15722393989562988, 0.025101184844970703, 0.057779788970947266, 0.01852703094482422, 0.045661211013793945]
# ...
