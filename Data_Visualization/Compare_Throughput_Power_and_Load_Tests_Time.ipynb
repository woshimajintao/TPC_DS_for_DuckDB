# %%
import matplotlib.pyplot as plt


#Power test data
sc_1_power_all = 4.038451194763184
sc_3_power_all = 8.463672876358032
sc_5_power_all = 13.16655683517456
sc_7_power_all = 18.318691968917847
#Throughout test data

values = [9.796560049057007,9.917084217071533,9.99402403831482,10.049023866653442]
max_tp1_sc1 = max(values)
values = [10.210510015487671,10.298335790634155,10.38304615020752,10.479890823364258]
max_tp2_sc1 = max(values)
values = [23.570493936538696,24.86452007293701,25.17958092689514,25.97860026359558]
max_tp1_sc3 = max(values)
values = [23.210995197296143,24.433070182800293,25.97832703590393,26.447018146514893]
max_tp2_sc3 = max(values)
values = [40.74530911445618,41.93079423904419,42.34715414047241,43.3882110118866]
max_tp1_sc5 = max(values)
values = [41.592230796813965,42.5003399848938,42.88273882865906,44.39180278778076]
max_tp2_sc5 = max(values)
values = [61.44860005378723,61.77061891555786,65.5444848537445,65.82219982147217]
max_tp1_sc7 = max(values)
values = [53.79103684425354,55.188393115997314,58.78313136100769,61.07700705528259]
max_tp2_sc7 = max(values)


x = [ 1, 3, 5,7]
y1 = [11.4066162109375,26.616861820220947,45.199235916137695,73.29852485656738]
y2 = [sc_1_power_all,sc_3_power_all,sc_5_power_all,sc_7_power_all]
#y3 = [max_tp1_sc1, max_tp1_sc3, max_tp1_sc5, max_tp1_sc7]
#y4 = [max_tp2_sc1, max_tp2_sc3, max_tp2_sc5, max_tp2_sc7]

plt.plot(x, y1, color='red', label='Load Test Time')
plt.plot(x, y2, color='green', label='Power Test Time')
plt.plot(x, y3, color='blue', label='Throughput Test Time1')
plt.plot(x, y4, color='yellow', label=' Throughput Test Time2')
plt.xticks([1, 3, 5, 7])
plt.title('Throughput, Power and Load Tests Time for the 4 scale factors')
plt.xlabel('Scale Factors')
plt.ylabel('Execution Time(Seconds)')
plt.legend()


plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# 为柱状图上的每一个柱子添加数据标签
#def autolabel(rects, ax):
 #   """Attach a text label above each bar in *rects*, displaying its height."""
  #  for rect in rects:
   #     height = rect.get_height()
    #    ax.annotate('{}'.format(height),
     #               xy=(rect.get_x() + rect.get_width() / 2, height),
      #              xytext=(0, 3),  # 3 points vertical offset
       #             textcoords="offset points",
        #            ha='center', va='bottom')

# 定义数据
# 标签和数据
#Power test data
sc_1_power_all = 4.038451194763184
sc_3_power_all = 8.463672876358032
sc_5_power_all = 13.16655683517456
sc_7_power_all = 18.318691968917847
#Throughout test data

values = [9.796560049057007,9.917084217071533,9.99402403831482,10.049023866653442]
max_tp1_sc1 = max(values)
values = [10.210510015487671,10.298335790634155,10.38304615020752,10.479890823364258]
max_tp2_sc1 = max(values)
values = [23.570493936538696,24.86452007293701,25.17958092689514,25.97860026359558]
max_tp1_sc3 = max(values)
values = [23.210995197296143,24.433070182800293,25.97832703590393,26.447018146514893]
max_tp2_sc3 = max(values)
values = [40.74530911445618,41.93079423904419,42.34715414047241,43.3882110118866]
max_tp1_sc5 = max(values)
values = [41.592230796813965,42.5003399848938,42.88273882865906,44.39180278778076]
max_tp2_sc5 = max(values)
values = [61.44860005378723,61.77061891555786,65.5444848537445,65.82219982147217]
max_tp1_sc7 = max(values)
values = [53.79103684425354,55.188393115997314,58.78313136100769,61.07700705528259]
max_tp2_sc7 = max(values)



labels = ['1', '3', '5', '7']
y1 = [11.4066162109375,26.616861820220947,45.199235916137695,73.29852485656738]
y1 = [round(num, 2) for num in y1]
y2 = [sc_1_power_all,sc_3_power_all,sc_5_power_all,sc_7_power_all]
y2 = [round(num, 2) for num in y2]
y3 = [max_tp1_sc1, max_tp1_sc3, max_tp1_sc5, max_tp1_sc7]
y3 = [round(num, 2) for num in y3]
y4 = [max_tp2_sc1, max_tp2_sc3, max_tp2_sc5, max_tp2_sc7]
y4 = [round(num, 2) for num in y4]

#labels = ['A', 'B', 'C', 'D', 'E']
#bar1_values = [10, 15, 9, 14, 13]
#bar2_values = [14, 9, 14, 10, 8]
#bar3_values = [8, 13, 14, 10, 12]
#bar4_values = [15, 14, 10, 9, 14]



x = np.arange(len(labels))  # 位置标签
width = 0.2  # 柱子的宽度

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - 1.5*width, y1, width, label='Load Test Time', color='r')
rects2 = ax.bar(x - 0.5*width, y2, width, label='Power Test Time', color='g')
rects3 = ax.bar(x + 0.5*width, y3, width, label='Throughput Test Time1', color='b')
rects4 = ax.bar(x + 1.5*width, y4, width, label='Throughput Test Time2', color='y')

# 调用autolabel函数给每个柱子添加标签
#autolabel(rects1, ax)
#autolabel(rects2, ax)
#autolabel(rects3, ax)
#autolabel(rects4, ax)

def autolabel(rects, ax,fontsize=10):
    """给柱子上方添加标签"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
# 调用autolabel函数给每个柱子添加标签
autolabel(rects1, ax,fontsize=5)
autolabel(rects2, ax,fontsize=5)
autolabel(rects3, ax,fontsize=5)
autolabel(rects4, ax,fontsize=5)


# 添加文本标签，标题和图例
ax.set_ylabel('Execution Time(Seconds)')
ax.set_xlabel('Scale Factors')
ax.set_title('Throughput, Power and Load Tests Time for the 4 scale factors')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# 使布局更为紧凑
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt


#Power test data
sc_1_power_all = 4.038451194763184
sc_3_power_all = 8.463672876358032
sc_5_power_all = 13.16655683517456
sc_7_power_all = 18.318691968917847
#Throughout test data

#values = [9.796560049057007,9.917084217071533,9.99402403831482,10.049023866653442]
#max_tp1_sc1 = max(values)
#values = [10.210510015487671,10.298335790634155,10.38304615020752,10.479890823364258]
#max_tp2_sc1 = max(values)
#values = [23.570493936538696,24.86452007293701,25.17958092689514,25.97860026359558]
#max_tp1_sc3 = max(values)
#values = [23.210995197296143,24.433070182800293,25.97832703590393,26.447018146514893]
#max_tp2_sc3 = max(values)
#values = [40.74530911445618,41.93079423904419,42.34715414047241,43.3882110118866]
#max_tp1_sc5 = max(values)
#values = [41.592230796813965,42.5003399848938,42.88273882865906,44.39180278778076]
#max_tp2_sc5 = max(values)
#values = [61.44860005378723,61.77061891555786,65.5444848537445,65.82219982147217]
#max_tp1_sc7 = max(values)
#values = [53.79103684425354,55.188393115997314,58.78313136100769,61.07700705528259]
#max_tp2_sc7 = max(values)


x = [ 1, 3, 5,7]
y1 = [11.4066162109375,26.616861820220947,45.199235916137695,73.29852485656738]
y2 = [sc_1_power_all,sc_3_power_all,sc_5_power_all,sc_7_power_all]
#y3 = [max_tp1_sc1, max_tp1_sc3, max_tp1_sc5, max_tp1_sc7]
#y4 = [max_tp2_sc1, max_tp2_sc3, max_tp2_sc5, max_tp2_sc7]

plt.plot(x, y1, color='red', label='Load Test Time')
plt.plot(x, y2, color='green', label='Power Test Time')
#plt.plot(x, y3, color='blue', label='Throughput Test Time1')
#plt.plot(x, y4, color='yellow', label=' Throughput Test Time2')
plt.xticks([1, 3, 5, 7])
plt.title('Load and Power Tests Time for the 4 scale factors')
plt.xlabel('Scale Factors')
plt.ylabel('Execution Time(Seconds)')
plt.legend()


plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# 为柱状图上的每一个柱子添加数据标签
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# 定义数据
# 标签和数据
#Power test data
sc_1_power_all = 4.038451194763184
sc_3_power_all = 8.463672876358032
sc_5_power_all = 13.16655683517456
sc_7_power_all = 18.318691968917847
#Throughout test data

#values = [9.796560049057007,9.917084217071533,9.99402403831482,10.049023866653442]
#max_tp1_sc1 = max(values)
#values = [10.210510015487671,10.298335790634155,10.38304615020752,10.479890823364258]
#max_tp2_sc1 = max(values)
#values = [23.570493936538696,24.86452007293701,25.17958092689514,25.97860026359558]
#max_tp1_sc3 = max(values)
#values = [23.210995197296143,24.433070182800293,25.97832703590393,26.447018146514893]
#max_tp2_sc3 = max(values)
#values = [40.74530911445618,41.93079423904419,42.34715414047241,43.3882110118866]
#max_tp1_sc5 = max(values)
#values = [41.592230796813965,42.5003399848938,42.88273882865906,44.39180278778076]
#max_tp2_sc5 = max(values)
#values = [61.44860005378723,61.77061891555786,65.5444848537445,65.82219982147217]
#max_tp1_sc7 = max(values)
#values = [53.79103684425354,55.188393115997314,58.78313136100769,61.07700705528259]
#max_tp2_sc7 = max(values)



labels = ['1', '3', '5', '7']
y1 = [11.4066162109375,26.616861820220947,45.199235916137695,73.29852485656738]
y1 = [round(num, 2) for num in y1]
print(y1)
y2 = [sc_1_power_all,sc_3_power_all,sc_5_power_all,sc_7_power_all]
y2 = [round(num, 2) for num in y2]
print(y2)
y3 = [max_tp1_sc1, max_tp1_sc3, max_tp1_sc5, max_tp1_sc7]
y3 = [round(num, 2) for num in y3]
print(y3)
y4 = [max_tp2_sc1, max_tp2_sc3, max_tp2_sc5, max_tp2_sc7]
y4 = [round(num, 2) for num in y4]
print(y4)

#labels = ['A', 'B', 'C', 'D', 'E']
#bar1_values = [10, 15, 9, 14, 13]
#bar2_values = [14, 9, 14, 10, 8]
#bar3_values = [8, 13, 14, 10, 12]
#bar4_values = [15, 14, 10, 9, 14]



x = np.arange(len(labels))  # 位置标签
width = 0.2  # 柱子的宽度

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - 0.5*width, y1, width, label='Load Test Time', color='r')
rects2 = ax.bar(x + 0.5*width, y2, width, label='Power Test Time', color='g')
#rects3 = ax.bar(x + 0.5*width, y3, width, label='Throughput Test Time1', color='b')
#rects4 = ax.bar(x + 1.5*width, y4, width, label='Throughput Test Time2', color='y')

# 调用autolabel函数给每个柱子添加标签
autolabel(rects1, ax)
autolabel(rects2, ax)
#autolabel(rects3, ax)
#autolabel(rects4, ax)

# 添加文本标签，标题和图例
ax.set_ylabel('Execution Time(Seconds)')
ax.set_xlabel('Scale Factors')
ax.set_title('Load and Power Tests Time for the 4 scale factors')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# 使布局更为紧凑
fig.tight_layout()

plt.show()
# Out:
# [11.41, 26.62, 45.2, 73.3]
# [4.04, 8.46, 13.17, 18.32]
# [10.05, 25.98, 43.39, 65.82]
# [10.48, 26.45, 44.39, 61.08]
